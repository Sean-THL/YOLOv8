# %% [markdown]
# <a href="https://colab.research.google.com/github/Sean-THL/YOLOv8/blob/main/Dronevis_train_YOLO_V11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="VisDrone.yaml", epochs=20, imgsz=640)
# Out:
# Ultralytics 8.3.248 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")  # pretrained YOLO11n model

# Run batched inference on a list of images
results = model("/content/datasets/VisDrone/images/train/0000072_05654_d_0000008.jpg",save=True)  # return a list of Results objects
# Out:
# image 1/1 /content/datasets/VisDrone/images/train/0000072_05654_d_0000008.jpg: 384x640 31 pedestrians, 5 cars, 1 van, 1 tricycle, 10.6ms
# Speed: 2.7ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict3
